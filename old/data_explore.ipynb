# %%
import pandas as pd
import numpy as np
from gtfs_functions import Feed, gtfs_plots
import os
import folium
import networkx as nx
import matplotlib.pyplot as plt
from rich import print as rprint
import seaborn as sns

# %% [markdown]
# ## Loading data

# %%
feed = Feed("./STM GTFS/gtfs_stm.zip", busiest_date=False)

# %%
routes = feed.routes
trips = feed.trips
stops = feed.stops
stop_times = feed.stop_times
shapes = feed.shapes
segments = feed.segments
# Out:
# INFO:root:Reading "routes.txt".
# INFO:root:accessing trips
# INFO:root:Reading "trips.txt".
# INFO:root:Reading "stop_times.txt".
# INFO:root:_trips is defined in stop_times
# INFO:root:Reading "stops.txt".
# INFO:root:computing patterns
# INFO:root:Reading "shapes.txt".

# %% [markdown]
# ## Plotting a single trip of a given route

# %%
ROUTE_NAME = "61"

route_id = routes[routes["route_short_name"] == ROUTE_NAME]["route_id"].iloc[0]
trip_ids = trips[trips["route_id"] == route_id]["trip_id"].tolist()
first_trip_id = trip_ids[0]

geom_shape = shapes[
    shapes["shape_id"] == trips[trips["trip_id"] == first_trip_id]["shape_id"].iloc[0]
]

stop_seq = stop_times[stop_times["trip_id"] == first_trip_id].sort_values(
    by="stop_sequence"
)
stop_seq_ids = stop_seq["stop_id"].tolist()
stops_to_plot = stops[stops["stop_id"].isin(stop_seq_ids)]

# %%
m = folium.Map(location=[45.508888, -73.561668], zoom_start=12, tiles="cartodbpositron")

folium.GeoJson(geom_shape["geometry"].iloc[0]).add_to(m)

for index, row in stops_to_plot.iterrows():
    location = (row["stop_lat"], row["stop_lon"])
    folium.CircleMarker(
        location, tooltip=row["stop_name"], radius=2, color="red"
    ).add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b5bbe7a68bd6802ecb103485acb75aad {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b5bbe7a68bd6802ecb103485acb75aad&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b5bbe7a68bd6802ecb103485acb75aad = L.map(
#                 &quot;map_b5bbe7a68bd6802ecb103485acb75aad&quot;,
#                 {
#                     center: [45.508888, -73.561668],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cd2fdda9f5d8e0e028b529a64ba634b2 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b5bbe7a68bd6802ecb103485acb75aad);
#
#
#
#         function geo_json_06e8ef62f5ede1b10f27b25b2d26e7b5_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_06e8ef62f5ede1b10f27b25b2d26e7b5 = L.geoJson(null, {
#                 onEachFeature: geo_json_06e8ef62f5ede1b10f27b25b2d26e7b5_onEachFeature,
#
#         });
#
#         function geo_json_06e8ef62f5ede1b10f27b25b2d26e7b5_add (data) {
#             geo_json_06e8ef62f5ede1b10f27b25b2d26e7b5
#                 .addData(data)
#                 .addTo(map_b5bbe7a68bd6802ecb103485acb75aad);
#         }
#             geo_json_06e8ef62f5ede1b10f27b25b2d26e7b5_add({&quot;coordinates&quot;: [[-73.567613, 45.452884], [-73.567369, 45.45287], [-73.567472, 45.452657], [-73.56757, 45.452355], [-73.567948, 45.452362], [-73.5679, 45.452901], [-73.567897, 45.452937], [-73.567824, 45.453649], [-73.56782, 45.453685], [-73.567737, 45.454407], [-73.567724, 45.454521], [-73.567721, 45.454557], [-73.567721, 45.454639], [-73.56772, 45.454675], [-73.56766, 45.455368], [-73.567656, 45.455404], [-73.567585, 45.456061], [-73.56758, 45.456096], [-73.567538, 45.456501], [-73.567521, 45.456673], [-73.567518, 45.456708], [-73.56747, 45.45724], [-73.567468, 45.457276], [-73.56742, 45.457842], [-73.567417, 45.457878], [-73.567388, 45.45832], [-73.567382, 45.458418], [-73.56738, 45.458454], [-73.567319, 45.459237], [-73.567317, 45.459273], [-73.567256, 45.459865], [-73.567231, 45.460119], [-73.567228, 45.460154], [-73.567142, 45.461], [-73.56714, 45.461036], [-73.567082, 45.461779], [-73.567078, 45.46182], [-73.567078, 45.461887], [-73.567076, 45.461932], [-73.566991, 45.46266], [-73.566979, 45.46276], [-73.566974, 45.462805], [-73.566795, 45.464802], [-73.566789, 45.46488], [-73.566786, 45.464916], [-73.566587, 45.467128], [-73.566527, 45.467325], [-73.56651, 45.467377], [-73.566459, 45.467511], [-73.566431, 45.467571], [-73.566402, 45.467627], [-73.566053, 45.468075], [-73.566051, 45.468079], [-73.566049, 45.468083], [-73.566041, 45.468148], [-73.566028, 45.468183], [-73.565926, 45.468336], [-73.565659, 45.468704], [-73.565645, 45.468723], [-73.564335, 45.470476], [-73.563898, 45.471061], [-73.563867, 45.471101], [-73.563487, 45.471585], [-73.563405, 45.471688], [-73.563091, 45.472081], [-73.563051, 45.472144], [-73.563001, 45.472216], [-73.562949, 45.472278], [-73.562782, 45.472503], [-73.562514, 45.472872], [-73.562067, 45.473448], [-73.561655, 45.473992], [-73.561543, 45.474141], [-73.560968, 45.474882], [-73.560943, 45.474914], [-73.560419, 45.475608], [-73.560202, 45.475879], [-73.56006, 45.476105], [-73.559948, 45.476314], [-73.559904, 45.476393], [-73.559885, 45.476428], [-73.559419, 45.477232], [-73.559399, 45.477266], [-73.559141, 45.477708], [-73.559108, 45.477783], [-73.559061, 45.477886], [-73.559046, 45.477921], [-73.558999, 45.478054], [-73.558899, 45.478563], [-73.558892, 45.478599], [-73.558796, 45.479098], [-73.558772, 45.47922], [-73.558765, 45.479256], [-73.558657, 45.479912], [-73.558651, 45.479948], [-73.558517, 45.480596], [-73.558511, 45.480632], [-73.558392, 45.481205], [-73.558377, 45.48128], [-73.558343, 45.481316], [-73.558306, 45.481347], [-73.5583, 45.481352], [-73.558298, 45.481359], [-73.558183, 45.481962], [-73.558082, 45.482637], [-73.558082, 45.482639], [-73.558082, 45.482642], [-73.558108, 45.482783], [-73.558086, 45.482917], [-73.557904, 45.484049], [-73.557802, 45.484616], [-73.557674, 45.485277], [-73.557611, 45.485597], [-73.557446, 45.486568], [-73.557297, 45.487303], [-73.557288, 45.487347], [-73.557232, 45.487612], [-73.557141, 45.488044], [-73.557026, 45.488775], [-73.557026, 45.489031], [-73.557181, 45.489734], [-73.55731, 45.490265], [-73.557488, 45.490826], [-73.557465, 45.490885], [-73.557463, 45.490892], [-73.557465, 45.490898], [-73.557517, 45.491007], [-73.557584, 45.4911], [-73.557688, 45.491218], [-73.557841, 45.491372], [-73.557954, 45.491497], [-73.558053, 45.4916

# %% [markdown]
# ## Getting all stops on a route

# %%
ROUTE_NAME = "35"

route_id = routes[routes["route_short_name"] == ROUTE_NAME]["route_id"].iloc[0]

# get all stops on route 35
stops_on_route = stop_times[
    stop_times["trip_id"].isin(trips[trips["route_id"] == route_id]["trip_id"].tolist())
].drop_duplicates(subset=["stop_id"])

# plot
m = folium.Map(location=[45.508888, -73.561668], zoom_start=12, tiles="cartodbpositron")

for index, row in stops_on_route.iterrows():
    location = (row["stop_lat"], row["stop_lon"])
    folium.CircleMarker(
        location, tooltip=row["stop_name"], radius=2, color="red"
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a98e4b32d85e5b3aa44fb5cacd65dcab {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a98e4b32d85e5b3aa44fb5cacd65dcab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a98e4b32d85e5b3aa44fb5cacd65dcab = L.map(
#                 &quot;map_a98e4b32d85e5b3aa44fb5cacd65dcab&quot;,
#                 {
#                     center: [45.508888, -73.561668],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4043cfbf55498772b197a387b4309060 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a98e4b32d85e5b3aa44fb5cacd65dcab);
#
#
#             var circle_marker_842cfb5a58c423e4f353b66bafe3658e = L.circleMarker(
#                 [45.507283, -73.569604],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a98e4b32d85e5b3aa44fb5cacd65dcab);
#
#
#             circle_marker_842cfb5a58c423e4f353b66bafe3658e.bindTooltip(
#                 `&lt;div&gt;
#                      Station Place-des-Arts (Président-Kennedy / De Ble
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_ca460ddb493944f153c421085e0f31c8 = L.circleMarker(
#                 [45.505842, -73.570268],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a98e4b32d85e5b3aa44fb5cacd65dcab);
#
#
#             circle_marker_ca460ddb493944f153c421085e0f31c8.bindTooltip(
#                 `&lt;div&gt;
#                      De Maisonneuve / City-Councillors
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_3a55f19d92e431d2571d3f69800ee619 = L.circleMarker(
#                 [45.503783, -73.569406],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a98e4b32d85e5b3aa44fb5cacd65dcab);
#
#
#             circle_marker_3a55f19d92e431d2571d3f69800ee619.bindTooltip(
#                 `&lt;div&gt;
#                      Union / Sainte-Catherine
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_14e220cb187e26dc8677ce3bfadfb913 = L.circleMarker(
#                 [45.502481, -73.565254],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a98e4b32d85e5b3aa44fb5cacd65dcab);
#
#
#             circle_marker_14e220cb187e26dc8677ce3bfadfb913.bindTooltip(
#                 `&lt;div&gt;
#                      du Beaver Hall / Belmont
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_668559cd07e745455cb26da2c8b382b4 = L.circleMarker(
#                 [45.501435, -73.562133],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quo

# %% [markdown]
# ## Getting all routes for a given stop

# %%
stops
# Out:
#            stop_id  stop_code  \
# 0     STATION_M118      10118
# 1               43      10118
# 2            43-01      10118
# 3     STATION_M120      10120
# 4               42      10120
# ...            ...        ...
# 9039         60987      60987
# 9040         61121      61121
# 9041         61253      61253
# 9042         61274      61274
# 9043         58596      58596
#
#                                               stop_name   stop_lat   stop_lon  \
# 0                                     STATION ANGRIGNON  45.446466 -73.603118
# 1                                     Station Angrignon  45.446466 -73.603118
# 2                                     Station Angrignon  45.446319 -73.603835
# 3                                          STATION MONK  45.451158 -73.593242
# 4                                          Station Monk  45.451158 -73.593242
# ...                                                 ...        ...        ...
# 9039  Institut national de santé publique (Sainte-Marie  45.433289 -73.907005
# 9040      du Souvenir / du Boulevard (Hôpital Ste-Anne)  45.411347 -73.949240
# 9041                              Lakeshore / Macdonald  45.403753 -73.940191
# 9042                 SRB Pie-IX / Saint-Martin (zone B)  45.610343 -73.662089
# 9043                                   Gouin / No 18465  45.462695 -73.898241
#
#                                                stop_url  location_type  \
# 0                                                   NaN              1
# 1     http://www.stm.info/fr/infos/reseaux/metro/ang...              0
# 2                                                   NaN              2
# 3                                                   NaN              1
# 4       http://www.stm.info/fr/infos/reseaux/metro/monk              0
# ...                                                 ...            ...
# 9039        https://www.stm.info/fr/recherche#stq=60987              0
# 9040        https://www.stm.info/fr/recherche#stq=61121              0
# 9041        https://www.stm.info/fr/recherche#stq=61253              0
# 9042        https://www.stm.info/fr/recherche#stq=61274              0
# 9043        https://www.stm.info/fr/recherche#stq=58596              0
#
#      parent_station  wheelchair_boarding                    geometry
# 0               NaN                    1  POINT (-73.60312 45.44647)
# 1      STATION_M118                    1  POINT (-73.60312 45.44647)
# 2      STATION_M118                    1  POINT (-73.60384 45.44632)
# 3               NaN                    2  POINT (-73.59324 45.45116)
# 4      STATION_M120                    2  POINT (-73.59324 45.45116)
# ...             ...                  ...                         ...
# 9039            NaN                    2  POINT (-73.90700 45.43329)
# 9040            NaN                    2  POINT (-73.94924 45.41135)
# 9041            NaN                    1  POINT (-73.94019 45.40375)
# 9042            NaN                    1  POINT (-73.66209 45.61034)
# 9043            NaN                    2  POINT (-73.89824 45.46269)
#
# [9044 rows x 10 columns]

# %%
stop_times[stop_times["stop_code"] == 54305]["route_id"].unique()
# Out:
# array(['359', '45'], dtype=object)

# %% [markdown]
# ## Number of trips per route

# %%
num_trips = (
    trips.groupby(["route_id"]).nunique()["trip_id"].sort_values(ascending=False)
)

num_trips
# Out:
# route_id
# 1      3556
# 10     1742
# 100    2120
# 101     130
# 102    1552
#        ...
# 94     1811
# 95     1586
# 968     796
# 97     2129
# 99     1260
# Name: trip_id, Length: 220, dtype: int64

# %%
line_frequency = feed.lines_freq

# %%
line_frequency
# Out:
#      route_id         route_name  direction_id       window  min_per_trip  \
# 0           1  1 Ligne 1 - Verte             0    0:00-6:00             3
# 1           1  1 Ligne 1 - Verte             0  15:00-19:00             0
# 2           1  1 Ligne 1 - Verte             0  19:00-22:00             0
# 3           1  1 Ligne 1 - Verte             0  22:00-24:00             0
# 4           1  1 Ligne 1 - Verte             0    6:00-9:00             0
# ...       ...                ...           ...          ...           ...
# 2358       99        99 Villeray             1  15:00-19:00             1
# 2359       99        99 Villeray             1  19:00-22:00             2
# 2360       99        99 Villeray             1  22:00-24:00             2
# 2361       99        99 Villeray             1    6:00-9:00             2
# 2362       99        99 Villeray             1   9:00-15:00             1
#
#       ntrips                                           geometry    radius  \
# 0         93  LINESTRING (-73.60312 45.44647, -73.59324 45.4...  1.121834
# 1        444  LINESTRING (-73.60312 45.44647, -73.59324 45.4...  5.355850
# 2        254  LINESTRING (-73.60312 45.44647, -73.59324 45.4...  3.063932
# 3        141  LINESTRING (-73.60312 45.44647, -73.59324 45.4...  1.700844
# 4        271  LINESTRING (-73.60312 45.44647, -73.59324 45.4...  3.268999
# ...      ...                                                ...       ...
# 2358     144  LINESTRING (-73.59286 45.56888, -73.59302 45.5...  1.737033
# 2359      80  LINESTRING (-73.59286 45.56888, -73.59302 45.5...  0.965018
# 2360      50  LINESTRING (-73.59286 45.56888, -73.59302 45.5...  0.603136
# 2361      84  LINESTRING (-73.59286 45.56888, -73.59302 45.5...  1.013269
# 2362     212  LINESTRING (-73.59286 45.56888, -73.59302 45.5...  2.557298
#
#      fill_color
# 0     #e895b3ff
# 1     #0e8955ff
# 2     #3ab071ff
# 3     #55d992ff
# 4     #3ab071ff
# ...         ...
# 2358  #55d992ff
# 2359  #e895b3ff
# 2360  #d13870ff
# 2361  #e895b3ff
# 2362  #3ab071ff
#
# [2363 rows x 9 columns]

# %%
most_frequent_lines = (
    (
        line_frequency.groupby(["route_id", "route_name", "direction_id", "geometry"])[
            "ntrips"
        ]
    )
    .sum()
    .reset_index()
    .query("route_id != ['1', '2', '3', '4']")
    .sort_values(by="ntrips", ascending=False)
)

# %%
top_5_lines = most_frequent_lines["route_id"].unique()[:5]
most_frequent_lines
# Out:
#     route_id              route_name  direction_id  \
# 121      165     165 Côte-des-Neiges             0
# 95       141      141 Jean-Talon Est             0
# 97       141      141 Jean-Talon Est             1
# 122      165     165 Côte-des-Neiges             1
# 17       105          105 Sherbrooke             1
# ..       ...                     ...           ...
# 156       18             18 Beaubien             0
# 206      197            197 Rosemont             1
# 189      191  191 Broadway / Provost             1
# 65       126    126 Thimens / Grenet             0
# 188      191  191 Broadway / Provost             1
#
#                                               geometry  ntrips
# 121  LINESTRING (-73.57911 45.49565, -73.57922 45.4...    2094
# 95   LINESTRING (-73.59968 45.55985, -73.59966 45.5...    2053
# 97   LINESTRING (-73.53463 45.59652, -73.53481 45.5...    2006
# 122  LINESTRING (-73.64407 45.51603, -73.64410 45.5...    1992
# 17   LINESTRING (-73.60432 45.47375, -73.60439 45.4...    1846
# ..                                                 ...     ...
# 156  LINESTRING (-73.60465 45.53553, -73.60462 45.5...       4
# 206  LINESTRING (-73.57379 45.56095, -73.57385 45.5...       4
# 189  LINESTRING (-73.57926 45.48313, -73.57917 45.4...       3
# 65   LINESTRING (-73.70172 45.50671, -73.70171 45.5...       3
# 188  LINESTRING (-73.57926 45.48313, -73.57917 45.4...       2
#
# [593 rows x 5 columns]

# %%
line_frequency_plot = line_frequency[line_frequency["route_id"].isin(top_5_lines)]

line_frequency_plot
# Out:
#      route_id       route_name  direction_id       window  min_per_trip  \
# 81        105   105 Sherbrooke             0    0:00-6:00             4
# 82        105   105 Sherbrooke             0  15:00-19:00             0
# 83        105   105 Sherbrooke             0  19:00-22:00             0
# 84        105   105 Sherbrooke             0  22:00-24:00             1
# 85        105   105 Sherbrooke             0    6:00-9:00             0
# ...       ...              ...           ...          ...           ...
# 1965       67  67 Saint-Michel             0  15:00-19:00             0
# 1966       67  67 Saint-Michel             0  19:00-22:00             0
# 1967       67  67 Saint-Michel             0  22:00-24:00             1
# 1968       67  67 Saint-Michel             0    6:00-9:00             0
# 1969       67  67 Saint-Michel             0   9:00-15:00             0
#
#       ntrips                                           geometry    radius  \
# 81        74  LINESTRING (-73.64148 45.45453, -73.64160 45.4...  0.892642
# 82       416  LINESTRING (-73.64148 45.45453, -73.64160 45.4...  5.018094
# 83       185  LINESTRING (-73.64148 45.45453, -73.64160 45.4...  2.231604
# 84        85  LINESTRING (-73.64148 45.45453, -73.64160 45.4...  1.025332
# 85       254  LINESTRING (-73.64148 45.45453, -73.64160 45.4...  3.063932
# ...      ...                                                ...       ...
# 1965     544  LINESTRING (-73.55139 45.54693, -73.55144 45.5...  6.562123
# 1966     213  LINESTRING (-73.55139 45.54693, -73.55144 45.5...  2.569361
# 1967      99  LINESTRING (-73.55139 45.54693, -73.55144 45.5...  1.194210
# 1968     202  LINESTRING (-73.55139 45.54693, -73.55144 45.5...  2.436671
# 1969     540  LINESTRING (-73.55139 45.54693, -73.55144 45.5...  6.513872
#
#      fill_color
# 81    #e895b3ff
# 82    #0e8955ff
# 83    #55d992ff
# 84    #e895b3ff
# 85    #3ab071ff
# ...         ...
# 1965  #066a40ff
# 1966  #3ab071ff
# 1967  #e895b3ff
# 1968  #3ab071ff
# 1969  #066a40ff
#
# [68 rows x 9 columns]
